# %%
import pandas as pd
from os import listdir
import datetime

# %%
csv_files = listdir('.')

# %%
all_data = pd.DataFrame()
for i, file in enumerate(csv_files[:10]):
    month = file[:2]
    day = file[3:5]
    time_start = datetime.time(hour=int(file[6:8]),
              minute=int(file[8:10]),
              second=int(file[10:12]))
    cycle_nb = file[13:16]
    mode = file[21]
    
    data_df = pd.read_csv(file)
    data_df['month'] = month
    data_df['day'] = day
    data_df['time_start'] = time_start
    data_df['cycle_nb'] = cycle_nb
    data_df['mode'] = mode
    
    #all_data = pd.concat([all_data, data_df])
# Out:
#   Input In [61]
#     data_df[''] =
#                   ^
# SyntaxError: invalid syntax

# %%
month = csv_files[0][:2]
day = csv_files[0][3:5]
time_start = csv_files[0][6:12]
cycle_nb = csv_files[0][13:16]
mode = csv_files[0][21]

# %%
datetime.time(hour=int(time_start[:2]),
              minute=int(time_start[2:4]),
              second=int(time_start[4:]))
# Out:
# datetime.time(15, 39, 37)

# %%
int(time_start[4:])
# Out:
# 37

# %%
data_df = pd.read_csv(csv_files[0])
# Out:
#       timestamp  pCut::Motor_Torque  \
# 0      0.008000           -1.303407
# 1      0.012000           -1.686989
# 2      0.016000           -1.446094
# 3      0.020000           -1.345243
# 4      0.024000           -1.374970
# ...         ...                 ...
# 2043   8.179999            0.413955
# 2044   8.183999            0.393422
# 2045   8.187999            0.474173
# 2046   8.191999            0.363579
# 2047   8.195999            0.317246
#
#       pCut::CTRL_Position_controller::Lag_error  \
# 0                                     -0.114562
# 1                                      0.001643
# 2                                     -0.030732
# 3                                     -0.107576
# 4                                     -0.053381
# ...                                         ...
# 2043                                   0.028749
# 2044                                   0.014661
# 2045                                  -0.018325
# ...
